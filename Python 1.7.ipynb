# %% [markdown]
# import pandas!

# %%
import pandas as pd

# %% [markdown]
# Load all the dataframes

# %%
suppliers = pd.read_csv("./data/suppliers.csv")
demand = pd.read_csv("./data/demand_forecasts.csv")
recipes = pd.read_csv("./data/recipes.csv")

# %%
suppliers
# Out:
#      supp_id ingredient_uuid  cost_per_unit unit_name country_of_origin  \
# 0   megacorp           cocoa         2500.0     tonne             ghana
# 1   megacorp     milk_powder         3200.0     tonne            france
# 2   megacorp        hazelnut         1918.0     tonne            turkey
# 3   megacorp           sugar          457.0     tonne            brazil
# 4   megacorp         vanilla          237.0     tonne             china
# 5   omni_inc           cocoa         2400.0     tonne     cote d'ivoire
# 6   omni_inc     milk_powder         3120.0     tonne       switzerland
# 7   omni_inc        hazelnut         1925.0     tonne             italy
# 8   omni_inc           sugar          465.0     tonne             india
# 9   omni_inc         vanilla          201.0     tonne         indonesia
# 10  acme_inc           cocoa         2370.0     tonne         indonesia
# 11  acme_inc     milk_powder         3190.0     tonne           denmark
# 12  acme_inc        hazelnut         1817.0     tonne               usa
# 13  acme_inc           sugar          476.0     tonne             china
# 14  acme_inc         vanilla          185.0     tonne        madagascar
#
#     total_tax_per_unit  time_to_deliver
# 0                   14               12
# 1                   12                3
# 2                   12                4
# 3                    5                9
# 4                    3               10
# 5                   14               12
# 6                    0                2
# 7                   12                3
# 8                    5               12
# 9                    3               12
# 10                  14               12
# 11                  12                3
# 12                  12                8
# 13                   5               10
# 14                   3               12

# %%
demand
# Out:
#     rec_id month  demand
# 0        1   jan   16443
# 1        1   feb   18943
# 2        1   mar   19727
# 3        1   apr   10368
# 4        1   may   15125
# 5        1   jun   18413
# 6        1   jul   17442
# 7        1   aug   19986
# 8        1   sep   15302
# 9        1   oct   13637
# 10       1   nov   16877
# 11       1   dec   15290
# 12       2   jan   14779
# 13       2   feb   14568
# 14       2   mar   11552
# 15       2   apr   10552
# 16       2   may   13765
# 17       2   jun   14758
# 18       2   jul   11285
# 19       2   aug   10799
# 20       2   sep   13370
# 21       2   oct   13686
# 22       2   nov   11628
# 23       2   dec   11724
# 24       3   jan   12356
# 25       3   feb   14191
# 26       3   mar   10613
# 27       3   apr   10261
# 28       3   may   10111
# 29       3   jun   16552
# 30       3   jul   12428
# 31       3   aug   19101
# 32       3   sep   10577
# 33       3   oct   10309
# 34       3   nov   15003
# 35       3   dec   13065

# %%
recipes
# Out:
#     rec_id ingredient_uuid  cost_to_process  time_to_process  qty
# 0        1           cocoa             0.20              120   10
# 1        1     milk_powder             0.03              110    2
# 2        1        hazelnut             0.08               45    1
# 3        1           sugar             0.40               80    4
# 4        2         vanilla             0.10               34    4
# 5        2           cocoa             0.20              120   11
# 6        2     milk_powder             0.03              110    3
# 7        2           sugar             0.40               80    3
# 8        3        hazelnut             0.08               45    1
# 9        3         vanilla             0.10               34    1
# 10       3           cocoa             0.20              120   11
# 11       3     milk_powder             0.03               11    3
# 12       3           sugar             0.40               80    4

# %%
#examples

# %%
suppliers.loc[3]
# Out:
# supp_id               megacorp
# ingredient_uuid          sugar
# cost_per_unit            457.0
# unit_name                tonne
# country_of_origin       brazil
# total_tax_per_unit           5
# time_to_deliver              9
# Name: 3, dtype: object

# %%
suppliers.iloc[3]
# Out:
# supp_id               megacorp
# ingredient_uuid          sugar
# cost_per_unit            457.0
# unit_name                tonne
# country_of_origin       brazil
# total_tax_per_unit           5
# time_to_deliver              9
# Name: 3, dtype: object

# %%
suppliers = suppliers.sort_values("country_of_origin")

# %%
suppliers
# Out:
#      supp_id ingredient_uuid  cost_per_unit unit_name country_of_origin  \
# 3   megacorp           sugar          457.0     tonne            brazil
# 4   megacorp         vanilla          237.0     tonne             china
# 13  acme_inc           sugar          476.0     tonne             china
# 5   omni_inc           cocoa         2400.0     tonne     cote d'ivoire
# 11  acme_inc     milk_powder         3190.0     tonne           denmark
# 1   megacorp     milk_powder         3200.0     tonne            france
# 0   megacorp           cocoa         2500.0     tonne             ghana
# 8   omni_inc           sugar          465.0     tonne             india
# 9   omni_inc         vanilla          201.0     tonne         indonesia
# 10  acme_inc           cocoa         2370.0     tonne         indonesia
# 7   omni_inc        hazelnut         1925.0     tonne             italy
# 14  acme_inc         vanilla          185.0     tonne        madagascar
# 6   omni_inc     milk_powder         3120.0     tonne       switzerland
# 2   megacorp        hazelnut         1918.0     tonne            turkey
# 12  acme_inc        hazelnut         1817.0     tonne               usa
#
#     total_tax_per_unit  time_to_deliver
# 3                    5                9
# 4                    3               10
# 13                   5               10
# 5                   14               12
# 11                  12                3
# 1                   12                3
# 0                   14               12
# 8                    5               12
# 9                    3               12
# 10                  14               12
# 7                   12                3
# 14                   3               12
# 6                    0                2
# 2                   12                4
# 12                  12                8

# %%
suppliers.loc[3]
# Out:
# supp_id               megacorp
# ingredient_uuid          sugar
# cost_per_unit            457.0
# unit_name                tonne
# country_of_origin       brazil
# total_tax_per_unit           5
# time_to_deliver              9
# Name: 3, dtype: object

# %%
suppliers.iloc[3]
# Out:
# supp_id                    omni_inc
# ingredient_uuid               cocoa
# cost_per_unit                2400.0
# unit_name                     tonne
# country_of_origin     cote d'ivoire
# total_tax_per_unit               14
# time_to_deliver                  12
# Name: 5, dtype: object

# %%
#Selection using masks

# %%
suppliers["cost_per_unit"] > 1000
# Out:
# 3     False
# 4     False
# 13    False
# 5      True
# 11     True
# 1      True
# 0      True
# 8     False
# 9     False
# 10     True
# 7      True
# 14    False
# 6      True
# 2      True
# 12     True
# Name: cost_per_unit, dtype: bool

# %%
suppliers[suppliers["cost_per_unit"] > 1000]
# Out:
#      supp_id ingredient_uuid  cost_per_unit unit_name country_of_origin  \
# 5   omni_inc           cocoa         2400.0     tonne     cote d'ivoire
# 11  acme_inc     milk_powder         3190.0     tonne           denmark
# 1   megacorp     milk_powder         3200.0     tonne            france
# 0   megacorp           cocoa         2500.0     tonne             ghana
# 10  acme_inc           cocoa         2370.0     tonne         indonesia
# 7   omni_inc        hazelnut         1925.0     tonne             italy
# 6   omni_inc     milk_powder         3120.0     tonne       switzerland
# 2   megacorp        hazelnut         1918.0     tonne            turkey
# 12  acme_inc        hazelnut         1817.0     tonne               usa
#
#     total_tax_per_unit  time_to_deliver
# 5                   14               12
# 11                  12                3
# 1                   12                3
# 0                   14               12
# 10                  14               12
# 7                   12                3
# 6                    0                2
# 2                   12                4
# 12                  12                8

# %%
suppliers.loc[suppliers["cost_per_unit"] > 1000]
# Out:
#      supp_id ingredient_uuid  cost_per_unit unit_name country_of_origin  \
# 5   omni_inc           cocoa         2400.0     tonne     cote d'ivoire
# 11  acme_inc     milk_powder         3190.0     tonne           denmark
# 1   megacorp     milk_powder         3200.0     tonne            france
# 0   megacorp           cocoa         2500.0     tonne             ghana
# 10  acme_inc           cocoa         2370.0     tonne         indonesia
# 7   omni_inc        hazelnut         1925.0     tonne             italy
# 6   omni_inc     milk_powder         3120.0     tonne       switzerland
# 2   megacorp        hazelnut         1918.0     tonne            turkey
# 12  acme_inc        hazelnut         1817.0     tonne               usa
#
#     total_tax_per_unit  time_to_deliver
# 5                   14               12
# 11                  12                3
# 1                   12                3
# 0                   14               12
# 10                  14               12
# 7                   12                3
# 6                    0                2
# 2                   12                4
# 12                  12                8

# %%
(suppliers["cost_per_unit"] < 1000) & (suppliers["ingredient_uuid"] == "sugar")
# Out:
# 3      True
# 4     False
# 13     True
# 5     False
# 11    False
# 1     False
# 0     False
# 8      True
# 9     False
# 10    False
# 7     False
# 14    False
# 6     False
# 2     False
# 12    False
# dtype: bool

# %%
#operations on cols

# %%
suppliers['cost_per_unit']*suppliers['total_tax_per_unit']
# Out:
# 3      2285.0
# 4       711.0
# 13     2380.0
# 5     33600.0
# 11    38280.0
# 1     38400.0
# 0     35000.0
# 8      2325.0
# 9       603.0
# 10    33180.0
# 7     23100.0
# 14      555.0
# 6         0.0
# 2     23016.0
# 12    21804.0
# dtype: float64

# %%
#oopsie
suppliers['cost_per_unit'] + suppliers['unit_name']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/ops/array_ops.py in _na_arithmetic_op(left, right, op, is_cmp)
#     141     try:
# --> 142         result = expressions.evaluate(op, left, right)
#     143     except TypeError:
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/computation/expressions.py in evaluate(op, a, b, use_numexpr)
#     234             # error: "None" not callable
# --> 235             return _evaluate(op, op_str, a, b)  # type: ignore[misc]
#     236     return _evaluate_standard(op, op_str, a, b)
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/computation/expressions.py in _evaluate_numexpr(op, op_str, a, b)
#     119     if result is None:
# --> 120         result = _evaluate_standard(op, op_str, a, b)
#     121
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/computation/expressions.py in _evaluate_standard(op, op_str, a, b)
#      68     with np.errstate(all="ignore"):
# ---> 69         return op(a, b)
#      70
#
# TypeError: unsupported operand type(s) for +: 'float' and 'str'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-24-57437b26295a> in <module>
#       1 #oopsie
# ----> 2 suppliers['cost_per_unit'] + suppliers['unit_name']
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/ops/common.py in new_method(self, other)
#      63         other = item_from_zerodim(other)
#      64
# ---> 65         return method(self, other)
#      66
#      67     return new_method
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/arraylike.py in __add__(self, other)
#      87     @unpack_zerodim_and_defer("__add__")
#      88     def __add__(self, other):
# ---> 89         return self._arith_method(other, operator.add)
#      90
#      91     @unpack_zerodim_and_defer("__radd__")
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/series.py in _arith_method(self, other, op)
#    4996         lvalues = extract_array(self, extract_numpy=True)
#    4997         rvalues = extract_array(other, extract_numpy=True)
# -> 4998         result = ops.arithmetic_op(lvalues, rvalues, op)
#    4999
#    5000         return self._construct_result(result, name=res_name)
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/ops/array_ops.py in arithmetic_op(left, right, op)
#     187     else:
#     188         with np.errstate(all="ignore"):
# --> 189             res_values = _na_arithmetic_op(lvalues, rvalues, op)
#     190
#     191     return res_values
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/ops/array_ops.py in _na_arithmetic_op(left, right, op, is_cmp)
#     147             #  will handle complex numbers incorrectly, see GH#32047
#     148             raise
# --> 149         result = _masked_arith_op(left, right, op)
#     150
#     151     if is_cmp and (is_scalar(result) or result is NotImplemented):
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/ops/array_ops.py in _masked_arith_op(x, y, op)
#      89         if mask.any():
#      90             with np.errstate(all="ignore"):
# ---> 91                 result[mask] = op(xrav[mask], yrav[mask])
#      92
#      93     else:
#
# TypeError: unsupported operand type(s) for +: 'float' and 'str'

# %%
suppliers['country_of_origin'].isin(['denmark', 'italy'])
# Out:
# 3     False
# 4     False
# 13    False
# 5     False
# 11     True
# 1     False
# 0     False
# 8     False
# 9     False
# 10    False
# 7      True
# 14    False
# 6     False
# 2     False
# 12    False
# Name: country_of_origin, dtype: bool

# %%
suppliers[suppliers['country_of_origin'].isin(['denmark', 'italy'])]
# Out:
#      supp_id ingredient_uuid  cost_per_unit unit_name country_of_origin  \
# 11  acme_inc     milk_powder         3190.0     tonne           denmark
# 7   omni_inc        hazelnut         1925.0     tonne             italy
#
#     total_tax_per_unit  time_to_deliver
# 11                  12                3
# 7                   12                3

# %%
suppliers['supp_id'] == "megacorp"
# Out:
# 3      True
# 4      True
# 13    False
# 5     False
# 11    False
# 1      True
# 0      True
# 8     False
# 9     False
# 10    False
# 7     False
# 14    False
# 6     False
# 2      True
# 12    False
# Name: supp_id, dtype: bool

# %%
suppliers[suppliers['supp_id'] == "megacorp"]
# Out:
#     supp_id ingredient_uuid  cost_per_unit unit_name country_of_origin  \
# 3  megacorp           sugar          457.0     tonne            brazil
# 4  megacorp         vanilla          237.0     tonne             china
# 1  megacorp     milk_powder         3200.0     tonne            france
# 0  megacorp           cocoa         2500.0     tonne             ghana
# 2  megacorp        hazelnut         1918.0     tonne            turkey
#
#    total_tax_per_unit  time_to_deliver
# 3                   5                9
# 4                   3               10
# 1                  12                3
# 0                  14               12
# 2                  12                4

# %%
#homework

# %% [markdown]
# 1) try sorting each table by different cols
#
# what happens if you sort by a col with text in it?
#
# 2) what happens when you use loc and iloc after sorting?
#
# try selecting the same number using loc and iloc, and see what outcome you get in each case
#
# 3) try selecting
#
#
# 5) try selecting all recipies using "milk_powder"
#
# 6) try selecting all demand in the month of jan
#
# 7) try selecting all demand in the months of jan, feb, mar

# %%
#solution 1

suppliers.sort_values("supp_id")
# Out:
#      supp_id ingredient_uuid  cost_per_unit unit_name country_of_origin  \
# 13  acme_inc           sugar          476.0     tonne             china
# 11  acme_inc     milk_powder         3190.0     tonne           denmark
# 10  acme_inc           cocoa         2370.0     tonne         indonesia
# 14  acme_inc         vanilla          185.0     tonne        madagascar
# 12  acme_inc        hazelnut         1817.0     tonne               usa
# 3   megacorp           sugar          457.0     tonne            brazil
# 4   megacorp         vanilla          237.0     tonne             china
# 1   megacorp     milk_powder         3200.0     tonne            france
# 0   megacorp           cocoa         2500.0     tonne             ghana
# 2   megacorp        hazelnut         1918.0     tonne            turkey
# 5   omni_inc           cocoa         2400.0     tonne     cote d'ivoire
# 8   omni_inc           sugar          465.0     tonne             india
# 9   omni_inc         vanilla          201.0     tonne         indonesia
# 7   omni_inc        hazelnut         1925.0     tonne             italy
# 6   omni_inc     milk_powder         3120.0     tonne       switzerland
#
#     total_tax_per_unit  time_to_deliver
# 13                   5               10
# 11                  12                3
# 10                  14               12
# 14                   3               12
# 12                  12                8
# 3                    5                9
# 4                    3               10
# 1                   12                3
# 0                   14               12
# 2                   12                4
# 5                   14               12
# 8                    5               12
# 9                    3               12
# 7                   12                3
# 6                    0                2

# %%
#solution 2
suppliers = suppliers.sort_values("supp_id") #remeber to save the sorted version!
suppliers.loc[2] #this gives row with name (index) value 2
# Out:
# supp_id               megacorp
# ingredient_uuid       hazelnut
# cost_per_unit           1918.0
# unit_name                tonne
# country_of_origin       turkey
# total_tax_per_unit          12
# time_to_deliver              4
# Name: 2, dtype: object

# %%
suppliers.iloc[2] #this gives row in position 2
# Out:
# supp_id                acme_inc
# ingredient_uuid           cocoa
# cost_per_unit            2370.0
# unit_name                 tonne
# country_of_origin     indonesia
# total_tax_per_unit           14
# time_to_deliver              12
# Name: 10, dtype: object

# %% [markdown]
# 4*) try setting a new index ("country_of_origin" for example) and using loc to select. This can be a little confusing at first, but it's faster in the long run if the data is big!
#
# clue: suppliers.set_index("ingredient_uuid").loc['hazelnut']

# %%
q = suppliers.set_index("ingredient_uuid")

# %%
q
# Out:
#                   supp_id  cost_per_unit unit_name country_of_origin  \
# ingredient_uuid
# sugar            acme_inc          476.0     tonne             china
# milk_powder      acme_inc         3190.0     tonne           denmark
# cocoa            acme_inc         2370.0     tonne         indonesia
# vanilla          acme_inc          185.0     tonne        madagascar
# hazelnut         acme_inc         1817.0     tonne               usa
# sugar            megacorp          457.0     tonne            brazil
# vanilla          megacorp          237.0     tonne             china
# milk_powder      megacorp         3200.0     tonne            france
# cocoa            megacorp         2500.0     tonne             ghana
# hazelnut         megacorp         1918.0     tonne            turkey
# cocoa            omni_inc         2400.0     tonne     cote d'ivoire
# sugar            omni_inc          465.0     tonne             india
# vanilla          omni_inc          201.0     tonne         indonesia
# hazelnut         omni_inc         1925.0     tonne             italy
# milk_powder      omni_inc         3120.0     tonne       switzerland
#
#                  total_tax_per_unit  time_to_deliver
# ingredient_uuid
# sugar                             5               10
# milk_powder                      12                3
# cocoa                            14               12
# vanilla                           3               12
# hazelnut                         12                8
# sugar                             5                9
# vanilla                           3               10
# milk_powder                      12                3
# cocoa                            14               12
# hazelnut                         12                4
# cocoa                            14               12
# sugar                             5               12
# vanilla                           3               12
# hazelnut                         12                3
# milk_powder                       0                2

# %%
q.loc['hazelnut']
# Out:
#                   supp_id  cost_per_unit unit_name country_of_origin  \
# ingredient_uuid
# hazelnut         acme_inc         1817.0     tonne               usa
# hazelnut         megacorp         1918.0     tonne            turkey
# hazelnut         omni_inc         1925.0     tonne             italy
#
#                  total_tax_per_unit  time_to_deliver
# ingredient_uuid
# hazelnut                         12                8
# hazelnut                         12                4
# hazelnut                         12                3

# %%
#solution 5
recipes[recipes['ingredient_uuid'] == "milk_powder"]
# Out:
#     rec_id ingredient_uuid  cost_to_process  time_to_process  qty
# 1        1     milk_powder             0.03              110    2
# 6        2     milk_powder             0.03              110    3
# 11       3     milk_powder             0.03               11    3

# %%
demand[demand['month'] == "jan"]
# Out:
#     rec_id month  demand
# 0        1   jan   16443
# 12       2   jan   14779
# 24       3   jan   12356

# %%
#solution 6
demand[ (demand['month'] == "jan") | (demand['month'] == "feb") | (demand['month'] == "mar") ]
# Out:
#     rec_id month  demand
# 0        1   jan   16443
# 1        1   feb   18943
# 2        1   mar   19727
# 12       2   jan   14779
# 13       2   feb   14568
# 14       2   mar   11552
# 24       3   jan   12356
# 25       3   feb   14191
# 26       3   mar   10613

# %%
#or better
demand[demand['month'].isin(['jan', 'feb', 'mar'])]
# Out:
#     rec_id month  demand
# 0        1   jan   16443
# 1        1   feb   18943
# 2        1   mar   19727
# 12       2   jan   14779
# 13       2   feb   14568
# 14       2   mar   11552
# 24       3   jan   12356
# 25       3   feb   14191
# 26       3   mar   10613

# %%
##########################################################################################

# %%
#nb, by default non numeric cols dropped
#nb index is now the thing we grouped by
suppliers.groupby("supp_id").mean()
# Out:
#           cost_per_unit  total_tax_per_unit  time_to_deliver
# supp_id
# acme_inc         1607.6                 9.2              9.0
# megacorp         1662.4                 9.2              7.6
# omni_inc         1622.2                 6.8              8.2

# %%
#min, max, median, mode, mean, var...
suppliers.groupby("supp_id").max()
# Out:
#          ingredient_uuid  cost_per_unit unit_name country_of_origin  \
# supp_id
# acme_inc         vanilla         3190.0     tonne               usa
# megacorp         vanilla         3200.0     tonne            turkey
# omni_inc         vanilla         3120.0     tonne       switzerland
#
#           total_tax_per_unit  time_to_deliver
# supp_id
# acme_inc                  14               12
# megacorp                  14               12
# omni_inc                  14               12

# %%
suppliers.groupby("ingredient_uuid").min()
# Out:
#                   supp_id  cost_per_unit unit_name country_of_origin  \
# ingredient_uuid
# cocoa            acme_inc         2370.0     tonne     cote d'ivoire
# hazelnut         acme_inc         1817.0     tonne             italy
# milk_powder      acme_inc         3120.0     tonne           denmark
# sugar            acme_inc          457.0     tonne            brazil
# vanilla          acme_inc          185.0     tonne             china
#
#                  total_tax_per_unit  time_to_deliver
# ingredient_uuid
# cocoa                            14               12
# hazelnut                         12                3
# milk_powder                       0                2
# sugar                             5                9
# vanilla                           3               10

# %%
#nb this creates a multi index
#nb this show the min value from each column
q = suppliers.groupby(["ingredient_uuid", "supp_id"]).min()
q
# Out:
#                           cost_per_unit unit_name country_of_origin  \
# ingredient_uuid supp_id
# cocoa           acme_inc         2370.0     tonne         indonesia
#                 megacorp         2500.0     tonne             ghana
#                 omni_inc         2400.0     tonne     cote d'ivoire
# hazelnut        acme_inc         1817.0     tonne               usa
#                 megacorp         1918.0     tonne            turkey
#                 omni_inc         1925.0     tonne             italy
# milk_powder     acme_inc         3190.0     tonne           denmark
#                 megacorp         3200.0     tonne            france
#                 omni_inc         3120.0     tonne       switzerland
# sugar           acme_inc          476.0     tonne             china
#                 megacorp          457.0     tonne            brazil
#                 omni_inc          465.0     tonne             india
# vanilla         acme_inc          185.0     tonne        madagascar
#                 megacorp          237.0     tonne             china
#                 omni_inc          201.0     tonne         indonesia
#
#                           total_tax_per_unit  time_to_deliver
# ingredient_uuid supp_id
# cocoa           acme_inc                  14               12
#                 megacorp                  14               12
#                 omni_inc                  14               12
# hazelnut        acme_inc                  12                8
#                 megacorp                  12                4
#                 omni_inc                  12                3
# milk_powder     acme_inc                  12                3
#                 megacorp                  12                3
#                 omni_inc                   0                2
# sugar           acme_inc                   5               10
#                 megacorp                   5                9
#                 omni_inc                   5               12
# vanilla         acme_inc                   3               12
#                 megacorp                   3               10
#                 omni_inc                   3               12

# %%
#this will show only one column
q = suppliers.groupby(["ingredient_uuid"])['time_to_deliver'].max()
q
# Out:
# ingredient_uuid
# cocoa          12
# hazelnut        8
# milk_powder     3
# sugar          12
# vanilla        12
# Name: time_to_deliver, dtype: int64

# %% [markdown]
# so now loc works like this

# %%
#to select the outer level
q.loc[ "vanilla" ]
# Out:
#           cost_per_unit unit_name country_of_origin  total_tax_per_unit  \
# supp_id
# acme_inc          185.0     tonne        madagascar                   3
# megacorp          237.0     tonne             china                   3
# omni_inc          201.0     tonne         indonesia                   3
#
#           time_to_deliver
# supp_id
# acme_inc               12
# megacorp               10
# omni_inc               12

# %%
#to select both at once!
q.loc[('cocoa', 'acme_inc')]
# Out:
# cost_per_unit            2370.0
# unit_name                 tonne
# country_of_origin     indonesia
# total_tax_per_unit           14
# time_to_deliver              12
# Name: (cocoa, acme_inc), dtype: object

# %%
#homework

# %% [markdown]
# 1) groupby "country_of_origin", and find the cheapest price for each ingredient
#
# 2) groupby "country_of_origin", and find the lowest tax option for each ingredient
#
# 3) groupby "country_of_origin" and "supp_id", and find the cheapest price for each ingredient
#
# 4) try reseting index after groupby, does it do what you expect?
#
# 5) take demand, group it by month, and find the mean

# %%
#solution 1

suppliers.groupby("country_of_origin")['cost_per_unit'].min()
# Out:
# country_of_origin
# brazil            457.0
# china             237.0
# cote d'ivoire    2400.0
# denmark          3190.0
# france           3200.0
# ghana            2500.0
# india             465.0
# indonesia         201.0
# italy            1925.0
# madagascar        185.0
# switzerland      3120.0
# turkey           1918.0
# usa              1817.0
# Name: cost_per_unit, dtype: float64

# %%
suppliers.groupby("country_of_origin")['total_tax_per_unit'].min()
# Out:
# country_of_origin
# brazil            5
# china             3
# cote d'ivoire    14
# denmark          12
# france           12
# ghana            14
# india             5
# indonesia         3
# italy            12
# madagascar        3
# switzerland       0
# turkey           12
# usa              12
# Name: total_tax_per_unit, dtype: int64

# %%
suppliers.groupby(["country_of_origin", "supp_id"])['total_tax_per_unit'].min()#.to_frame()
# Out:
# country_of_origin  supp_id
# brazil             megacorp     5
# china              acme_inc     5
#                    megacorp     3
# cote d'ivoire      omni_inc    14
# denmark            acme_inc    12
# france             megacorp    12
# ghana              megacorp    14
# india              omni_inc     5
# indonesia          acme_inc    14
#                    omni_inc     3
# italy              omni_inc    12
# madagascar         acme_inc     3
# switzerland        omni_inc     0
# turkey             megacorp    12
# usa                acme_inc    12
# Name: total_tax_per_unit, dtype: int64

# %%
q = suppliers.groupby(["country_of_origin", "supp_id"])['total_tax_per_unit'].min()#.to_frame()
q.reset_index()
# Out:
#    country_of_origin   supp_id  total_tax_per_unit
# 0             brazil  megacorp                   5
# 1              china  acme_inc                   5
# 2              china  megacorp                   3
# 3      cote d'ivoire  omni_inc                  14
# 4            denmark  acme_inc                  12
# 5             france  megacorp                  12
# 6              ghana  megacorp                  14
# 7              india  omni_inc                   5
# 8          indonesia  acme_inc                  14
# 9          indonesia  omni_inc                   3
# 10             italy  omni_inc                  12
# 11        madagascar  acme_inc                   3
# 12       switzerland  omni_inc                   0
# 13            turkey  megacorp                  12
# 14               usa  acme_inc                  12

# %%
#solution 5
demand.groupby("month")['demand'].mean()
# Out:
# month
# apr    10393.666667
# aug    16628.666667
# dec    13359.666667
# feb    15900.666667
# jan    14526.000000
# jul    13718.333333
# jun    16574.333333
# mar    13964.000000
# may    13000.333333
# nov    14502.666667
# oct    12544.000000
# sep    13083.000000
# Name: demand, dtype: float64

# %%
demand.groupby("month")['demand'].mean().plot()

# %%
##########################################################################################
#idxmax and idxmin

# %%
demand['demand'].idxmax()
# Out:
# 7

# %%
demand.loc[demand['demand'].idxmax()]
# Out:
# rec_id        1
# month       aug
# demand    19986
# Name: 7, dtype: object

# %%
demand.groupby("month")['demand'].idxmax()
# Out:
# month
# apr    15
# aug     7
# dec    11
# feb     1
# jan     0
# jul     6
# jun     5
# mar     2
# may     4
# nov    10
# oct    21
# sep     8
# Name: demand, dtype: int64

# %%
demand.groupby("month").idxmax()
# Out:
#        rec_id  demand
# month
# apr        27      15
# aug        31       7
# dec        35      11
# feb        25       1
# jan        24       0
# jul        30       6
# jun        29       5
# mar        26       2
# may        28       4
# nov        34      10
# oct        33      21
# sep        32       8

# %%
demand.loc[demand.groupby("month")['demand'].idxmax()]
# Out:
#     rec_id month  demand
# 15       2   apr   10552
# 7        1   aug   19986
# 11       1   dec   15290
# 1        1   feb   18943
# 0        1   jan   16443
# 6        1   jul   17442
# 5        1   jun   18413
# 2        1   mar   19727
# 4        1   may   15125
# 10       1   nov   16877
# 21       2   oct   13686
# 8        1   sep   15302

# %%
demand['demand'].nlargest(3)
# Out:
# 7     19986
# 2     19727
# 31    19101
# Name: demand, dtype: int64

# %%
demand['demand'].nlargest(3).index
# Out:
# Int64Index([7, 2, 31], dtype='int64')

# %%
demand.loc[demand['demand'].nlargest(3).index]
# Out:
#     rec_id month  demand
# 7        1   aug   19986
# 2        1   mar   19727
# 31       3   aug   19101

# %%
##########################################################################################
##########################################################################################
##########################################################################################
##########################################################################################

#scenaio

# %% [markdown]
# Choose suppliers for each ingredient for each product.
# Select the cheapest option, and the least tax option, and the fastest option.

# %%
suppliers.groupby('ingredient_uuid')['cost_per_unit'].idxmin()

# %%
cheapest_supplier = suppliers.loc[suppliers.groupby('ingredient_uuid')['cost_per_unit'].idxmin()]
cheapest_supplier

# %%
suppliers.loc[suppliers.groupby('ingredient_uuid')['total_tax_per_unit'].idxmin()]

# %%
suppliers.loc[suppliers.groupby('ingredient_uuid')['time_to_deliver'].idxmin()]

# %% [markdown]
# Work out total demand for each ingredient, using the demand for each product by month, and over a year.

# %%
ingredient_demand = demand.merge(recipes, on='rec_id')
ingredient_demand

# %%
ingredient_demand['ingredient_demand'] = ingredient_demand['demand']*ingredient_demand['qty']
ingredient_demand

# %%
monthly_ingredient_demand = ingredient_demand.groupby(['ingredient_uuid','month'])[['ingredient_demand']].sum()
monthly_ingredient_demand

# %%
monthly_ingredient_demand.groupby('ingredient_uuid').plot(figsize=(10,10))

# %%
ingredient_demand.merge(cheapest_supplier, on='ingredient_uuid')
ingredient_demand['ingredient_demand'] = ingredient_demand['demand']*ingredient_demand['qty']
ingredient_demand

# %%
demand_by_supply = ingredient_demand.merge(cheapest_supplier, on='ingredient_uuid')
demand_by_supply['ingredient_cost'] = demand_by_supply['ingredient_demand']*demand_by_supply['cost_per_unit']
demand_by_supply

# %% [markdown]
# Work out total cost per unit to product

# %%
demand_by_supply.groupby('rec_id')['ingredient_cost'].sum()

# %%
demand_by_supply.groupby('rec_id')['ingredient_cost'].sum().plot.bar()

# %% [markdown]
# (Homework) work out how to find the total cost of goods needed for each producer country.

# %%
ingredient_demand.merge(cheapest_supplier, on="ingredient_uuid").groupby('country_of_origin').sum()

# %% [markdown]
# (Homework) work out how to find the total tax, using the cheapest supplier for each ingredient, to create 1000 of each recipe.

# %%
q = ingredient_demand.merge(cheapest_supplier, on="ingredient_uuid").groupby('ingredient_uuid').sum()
q[['total_tax_per_unit']]

# %%
q['total_tax_per_unit'].plot.bar(x = "ingredient_uuid", y="total_tax_per_unit")

# %%
q['total_cost'] = q['ingredient_demand']*q['cost_per_unit'] + q['ingredient_demand']*q['total_tax_per_unit']
q

# %%
q['total_cost'].plot.bar()

# %%
q[['total_cost', 'time_to_deliver']].plot.scatter(x='total_cost', y='time_to_deliver')

# %%
q = ingredient_demand.merge(cheapest_supplier, on="ingredient_uuid").groupby('ingredient_uuid')[['total_tax_per_unit']].sum()
q

# %%
from random import randint
import numpy as np

# %%
df = pd.read_csv("./data/demand_trend.csv", index_col=0)

df['date'] = pd.to_datetime(df['date'])
q = df[ ['date', 'demand'] ]
q.plot(x='date', y='demand', figsize=(10,10))

# %%
q

# %%
q.dropna()

# %%
df.fillna( df['demand'].mean() )

# %%
df.fillna( df['demand'].mean() )['demand'].plot()

# %%
df.fillna( method='ffill' )

# %%
df.fillna( method='bfill' )

# %%
df.fillna( method='ffill' ).fillna( method='bfill' )

# %%
df.fillna( method='ffill' ).fillna( method='bfill' )['demand'].plot()

# %%
df['day_of_year'] = df['date'].apply( lambda x : x.dayofyear )

df['week_of_year'] = df['date'].apply( lambda x : x.weekofyear )

df['day_of_week'] = df['date'].apply( lambda x : x.day_of_week )

df['is_month_start'] = df['date'].apply( lambda x : x.is_month_start )

df['month'] = df['date'].apply( lambda x : x.month )

# %%
df

# %%
df.fillna(df['demand'].mean()).groupby( 'week_of_year' )['demand'].sum().plot()

# %%
df.fillna(df['demand'].mean()).groupby( 'day_of_week' )['demand'].sum().plot.bar()

# %%
#homework : create a bar chart grouping all the data by month. Is any one month significantly higher than the others

# %%
#homework (research needed) : use diff + shift functions to work out rate of demand growth month/month and year / year
#take care to notice what happens with nan

# %%
from pandas.tseries.holiday import USFederalHolidayCalendar as calendar

# %%
cal = calendar()
holidays = cal.holidays(start=df['date'].min(), end=df['date'].max())

df['holiday'] = df['date'].isin(holidays)

# %%
df.groupby('holiday')['demand'].mean().plot.bar()

# %%
df['diff_day'] = df.fillna( method='ffill' ).fillna( method='bfill' )['demand'].diff(periods=1)

# %%
df.fillna( method='ffill' ).fillna( method='bfill' )['demand'].diff(periods=10)

# %%
df

# %%
df['demand_shift'] = df['demand'].shift(2)
df

# %%
df['dod_demand'] = df['demand'] / df['demand_shift']
df
