# %% [markdown]
# # Reading + Writing a file

# %%
myfile = open('./data/ex.txt', 'r')
print(myfile.readlines())

#be carful, if your code breaks here, the file will be left open!

myfile.close()

#this won't work as the file is now closed
print(myfile.readlines())
# Out:
# ['Sed ut perspiciatis unde omnis iste natus error sit voluptatem accusantium doloremque laudantium, totam rem aperiam, eaque ipsa quae ab illo inventore veritatis et quasi architecto beatae vitae dicta sunt explicabo.\n', 'Nemo enim ipsam voluptatem quia voluptas sit aspernatur aut odit aut fugit, sed quia consequuntur magni dolores eos qui ratione voluptatem sequi nesciunt. Neque porro quisquam est, qui dolorem ipsum quia dolor sit amet, consectetur, adipisci velit, sed quia non numquam eius modi tempora incidunt ut labore et dolore magnam aliquam quaerat voluptatem. Ut enim ad minima veniam, quis nostrum exercitationem ullam corporis suscipit laboriosam, nisi ut aliquid ex ea commodi consequatur?\n', 'Quis autem vel eum iure reprehenderit qui in ea voluptate velit esse quam nihil molestiae consequatur, vel illum qui dolorem eum fugiat quo voluptas nulla pariatur?\n']
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-135-c219d5aafcbd> in <module>
#       7
#       8 #this won't work as the file is now closed
# ----> 9 print(myfile.readlines())
#
# ValueError: I/O operation on closed file.

# %%
# Using the "with" method is far better, as it automatically closes the file after

with open('./data/ex.txt', 'r') as f:
    print(f.readlines())
# Out:
# ['Sed ut perspiciatis unde omnis iste natus error sit voluptatem accusantium doloremque laudantium, totam rem aperiam, eaque ipsa quae ab illo inventore veritatis et quasi architecto beatae vitae dicta sunt explicabo.\n', 'Nemo enim ipsam voluptatem quia voluptas sit aspernatur aut odit aut fugit, sed quia consequuntur magni dolores eos qui ratione voluptatem sequi nesciunt. Neque porro quisquam est, qui dolorem ipsum quia dolor sit amet, consectetur, adipisci velit, sed quia non numquam eius modi tempora incidunt ut labore et dolore magnam aliquam quaerat voluptatem. Ut enim ad minima veniam, quis nostrum exercitationem ullam corporis suscipit laboriosam, nisi ut aliquid ex ea commodi consequatur?\n', 'Quis autem vel eum iure reprehenderit qui in ea voluptate velit esse quam nihil molestiae consequatur, vel illum qui dolorem eum fugiat quo voluptas nulla pariatur?\n']

# %%
# Using the "generator" for file lines is also a great way not to load all the file at once! What if its huge!

with open('./data/ex.txt', 'r') as f:
    while line:
        print(line)
        line = f.readline()

# %% [markdown]
# # write a line

# %%
#oopsie, wrong mode!
with open('./data/ex2.txt', 'r') as f:
    f.write("this is a new line")
# Out:
# ---------------------------------------------------------------------------
# UnsupportedOperation                      Traceback (most recent call last)
# <ipython-input-64-6d32eb9dbb9f> in <module>
#       1 #oopsie, wrong mode!
#       2 with open('./data/ex2.txt', 'r') as f:
# ----> 3     f.write("this is a new line")
#
# UnsupportedOperation: not writable

# %%
#even this will blank your file!
#it won't ask, and it won't go to recycle bin!

with open('./data/ex3.txt', 'w') as f:
    pass

# %%
with open('./data/ex2.txt', 'w') as f:
    f.write("this is a new line\n")
    f.write("this is a new line")

# %%
with open('./data/ex2.txt', 'w') as f:
    f.write("this is a new line")

#nb, now there is only one line. The "w" means, opening will blank the file. CAUTION!

# %%
# mode a for append, to write to the end of the file
with open('./data/ex2.txt', 'a') as f:
    f.write("this is a new line\n")

# %%
#using """ """ can let you work with multi-line strings
with open('./data/ex2.txt', 'a') as f:
    #f.write("this is a new line\n")
    #f.write("this is a new file\nwith a new line")
    f.write("""
this is a new file

with a new line

and another
    """)

# %%
#compare with this
with open('./data/ex2.txt', 'a') as f:
    #f.write("this is a new line\n")
    f.write("this is a new file\nwith a new line")

# %%
with open('./data/ex2.txt', 'rb') as f:
    print(f.read())
# Out:
# b'\nthis is a new file\n\nwith a new line\n\nand another\n    \nthis is a new file\n\nwith a new line\n\nand another\n    '

# %%
#all the possible modes can be found here
# https://docs.python.org/3/library/functions.html#open

#important to be careful with "w" vs "a".

# %% [markdown]
# # Looping over all files in a folder

# %%
import os

#change to a path on your own machine!
directory = os.fsencode('/home/benjamin/Desktop/webinars/notebooks/data')
directory
# Out:
# b'/home/benjamin/Desktop/webinars/notebooks/data'

# %%
for file in os.listdir(directory):
    print( file )
# Out:
# b'eg1.xlsx'
# b'ex.txt'
# b'ex5.txt'
# b'examples'
# b'result.xlsx'
# b'ex2.txt'
# b'sampledatafoodsales.xlsx'
# b'ex3.txt'

# %%
#recursive
import glob

for filename in glob.iglob('/home/benjamin/Desktop/webinars/**/*.py', recursive=True):
    with open(filename, 'rb') as f:
        print("\n\n~~~~~~~~~~~~~~~~~~")
        print("\n", filename, "\n")
        try:
            print( f.readlines()[-3] )
        except Exception as e:
            print(repr(e))
# Out:
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/test.py
#
# b'print(x)\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/versioneer.py
#
# b'        errors += scan_setup_py()\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/setup.py
#
# b'        ext_modules=maybe_cythonize(extensions, compiler_directives=directives),\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/_version.py
#
# b'        "error": "unable to compute version",\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/__init__.py
#
# b'  - Time series-specific functionality: date range generation and frequency\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/conftest.py
#
# b'    Fixture to check if the array manager is being used.\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/_typing.py
#
# b'PositionalIndexer2D = Union[\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/testing.py
#
# b'    "assert_series_equal",\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/tseries/offsets.py
#
# b'    "Nano",\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/tseries/api.py
#
# b'\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/tseries/__init__.py
#
# IndexError('list index out of range')
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/tseries/frequencies.py
#
# b'def _is_weekly(rule: str) -> bool:\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/tseries/holiday.py
#
# b'    rules = AbstractHolidayCalendar.merge_class(base, other)\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/_testing/__init__.py
#
# b'\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/_testing/asserters.py
#
# b'    Related to issue #37609\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/_testing/compat.py
#
# b'        return obj.dtypes.iat[0]\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/_testing/_io.py
#
# b'            _close(fignum)\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/_testing/_warnings.py
#
# b'        f"{caller.filename}. Warning message: {actual_warning.message}"\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/_testing/_random.py
#
# b'\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/_testing/contexts.py
#
# b'    def __exit__(self, exc_type, exc_value, traceback):\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/api/__init__.py
#
# b'    indexers,\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/api/types/__init__.py
#
# b'    "IntervalDtype",\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/api/extensions/__init__.py
#
# b'    "ExtensionArray",\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/api/indexers/__init__.py
#
# b'    "FixedForwardWindowIndexer",\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/errors/__init__.py
#
# b'\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/compat/__init__.py
#
# b'    "pa_version_under3p0",\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/compat/chainmap.py
#
# b'                del mutable_mapping[key]\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/compat/pyarrow.py
#
# b'    pa_version_under3p0 = True\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/compat/pickle_compat.py
#
# b'        yield\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/compat/_optional.py
#
# b'                raise ImportError(msg)\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/compat/numpy/__init__.py
#
# b'    "_np_version",\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/compat/numpy/function.py
#
# b'        return\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/core/apply.py
#
# b'\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/core/generic.py
#
# b'                right.index = join_index\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/core/api.py
#
# b'\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/core/__init__.py
#
# IndexError('list index out of range')
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/core/describe.py
#
# b'        raise ValueError("percentiles cannot contain duplicates")\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/core/resample.py
#
# b'    else:  # pragma: no cover\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/core/sorting.py
#
# b'    uniques = uniques.take(sorter)\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/core/common.py
#
# b'    otherwise return the arg\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/core/config_init.py
#
# b'        styler_max_elements,\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/core/aggregation.py
#
# b'        no_arg_message = "Must provide \'func\' or named aggregation **kwargs."\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/core/sample.py
#
# b'    return random_state.choice(obj_len, size=size, replace=replace, p=weights).astype(\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/core/algorithms.py
#
# b'    for i, value in enumerate(unique_array):\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/core/accessor.py
#
# b'    from pandas import Index\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/core/arraylike.py
#
# b'    else:\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/core/frame.py
#
# b'            "incompatible index of inserted column with frame index"\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/core/roperator.py
#
# b'\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/core/construction.py
#
# b'    return Series(\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/core/shared_docs.py
#
# b'    4     b\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/core/indexing.py
#
# b'        or obj.stop is not None\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/core/flags.py
#
# b'        if isinstance(other, type(self)):\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/core/missing.py
#
# b'    shape = a.shape[:-1] + (a.shape[-1] - window + 1, window)\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/core/series.py
#
# b'\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/core/nanops.py
#
# b'        result = accum_func(values, axis=0)\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/core/index.py
#
# b'    FutureWarning,\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/core/base.py
#
# b'        self, keep: Literal["first", "last", False] = "first"\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/core/array_algos/__init__.py
#
# b'- Not depend on Index, Series, or DataFrame, nor import any of these.\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/core/array_algos/putmask.py
#
# b'                other = list(other)\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/core/array_algos/transforms.py
#
# b'        new_values = new_values.T\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/core/array_algos/take.py
#
# b'\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/core/array_algos/masked_reductions.py
#
# b'    count = np.count_nonzero(~mask)\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/core/array_algos/quantile.py
#
# b'        # for floating point output\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/core/array_algos/replace.py
#
# b'        values[:] = f(values)\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/core/window/expanding.py
#
# b'            window_indexer=ExpandingIndexer,\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/core/window/__init__.py
#
# b'    RollingGroupby,\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/core/window/numba_.py
#
# b'        return result\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/core/window/doc.py
#
# b'          .. versionadded:: 1.3.0\\n\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/core/window/rolling.py
#
# b'        """\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/core/window/ewm.py
#
# b'        result = result[result_from:]\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/core/window/common.py
#
# b'    X = arg1 + 0 * arg2\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/core/window/online.py
#
# b'    def reset(self):\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/core/ops/methods.py
#
# b'def _add_methods(cls, new_methods):\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/core/ops/array_ops.py
#
# b'            raise NotImplementedError(\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/core/ops/__init__.py
#
# b'    f.__name__ = op_name\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/core/ops/common.py
#
# b'    elif b_has:\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/core/ops/mask_ops.py
#
# b'def raise_for_nan(value, method: str):\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/core/ops/invalid.py
#
# b'\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/core/ops/dispatch.py
#
# b'    bool\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/core/ops/docstrings.py
#
# b'   B   True    False\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/core/ops/missing.py
#
# b'    elif op is roperator.rmod:\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/core/groupby/generic.py
#
# b'        return res_frame\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/core/groupby/__init__.py
#
# b'    "GroupBy",\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/core/groupby/categorical.py
#
# b'    new_cats = c.categories[~c.categories.isin(ci.categories)]\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/core/groupby/numba_.py
#
# b'        return result\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/core/groupby/groupby.py
#
# b'        mutated=mutated,\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/core/groupby/ops.py
#
# b'        klass = FrameSplitter\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/core/groupby/grouper.py
#
# b'            FutureWarning,\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/core/groupby/base.py
#
# b'# NOTE: do NOT edit this directly. New additions should be inserted\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/core/internals/api.py
#
# b'        else:\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/core/internals/concat.py
#
# b'                        next_items[i] = _next_or_none(plans[i])\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/core/internals/__init__.py
#
# b'        return CategoricalBlock\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/core/internals/array_manager.py
#
# b'            arr = np.empty(self.n, dtype=dtype)\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/core/internals/ops.py
#
# b'        if not res:\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/core/internals/managers.py
#
# b'        if not allow_fill:\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/core/internals/blocks.py
#
# b'        return values._data\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/core/internals/construction.py
#
# b'    arrays = [convert(arr) for arr in content]\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/core/internals/base.py
#
# b'        return None\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/core/computation/scope.py
#
# b'            + self.scope.maps  # type: ignore[operator]\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/core/computation/expressions.py
#
# b'    res = _TEST_RESULT\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/core/computation/api.py
#
# b'# flake8: noqa\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/core/computation/__init__.py
#
# IndexError('list index out of range')
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/core/computation/expr.py
#
# b'\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/core/computation/eval.py
#
# b'    # We want to exclude `inplace=None` as being False.\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/core/computation/ops.py
#
# b'\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/core/computation/common.py
#
# b'    except ValueError:\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/core/computation/parsing.py
#
# b'                raise SyntaxError(f"Failed to parse backticks in \'{source}\'.") from err\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/core/computation/engines.py
#
# b'    "numexpr": NumExprEngine,\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/core/computation/pytables.py
#
# b'\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/core/computation/align.py
#
# b'            ret_value = np.array([ret_value]).astype(res_t)\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/core/computation/check.py
#
# b'    NUMEXPR_VERSION = None\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/core/reshape/api.py
#
# b'    cut,\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/core/reshape/concat.py
#
# b'    return MultiIndex(\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/core/reshape/__init__.py
#
# IndexError('list index out of range')
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/core/reshape/reshape.py
#
# b'    #  c0r1, c1r1, c2r1, ...]\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/core/reshape/util.py
#
# b'    # Otherwise we have an Index\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/core/reshape/tile.py
#
# b'        if algos.unique(levels).size == bins.size:\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/core/reshape/melt.py
#
# b'    new = df[id_vars].merge(melted.reset_index(), on=i).set_index(i + [j])\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/core/reshape/merge.py
#
# b'        )\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/core/reshape/pivot.py
#
# b'    ]\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/core/arrays/__init__.py
#
# b'    "StringArray",\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/core/arrays/categorical.py
#
# b'\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/core/arrays/datetimelike.py
#
# b'            freq_infer = True\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/core/arrays/numpy_.py
#
# b'    # ------------------------------------------------------------------------\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/core/arrays/_mixins.py
#
# b'        arr = cls._from_sequence([], dtype=dtype)\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/core/arrays/_ranges.py
#
# b'    raise OutOfBoundsDatetime(\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/core/arrays/integer.py
#
# b'    "uint32": UInt32Dtype(),\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/core/arrays/masked.py
#
# b'            return libmissing.NA\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/core/arrays/numeric.py
#
# b'        nv.validate_round(args, kwargs)\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/core/arrays/string_arrow.py
#
# b'        else:\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/core/arrays/_arrow_utils.py
#
# b'# register the type with a dummy instance\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/core/arrays/timedeltas.py
#
# b'        raise ValueError(f"dtype {dtype} cannot be converted to timedelta64[ns]")\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/core/arrays/interval.py
#
# b'    if not hasattr(values, "dtype"):\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/core/arrays/floating.py
#
# b'    "float32": Float32Dtype(),\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/core/arrays/boolean.py
#
# b'        else:\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/core/arrays/string_.py
#
# b'            #    or .findall returns a list).\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/core/arrays/datetimes.py
#
# b'            if next_date >= cur:\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/core/arrays/period.py
#
# b'        else np.repeat(x, length)  # type: ignore[arg-type]\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/core/arrays/base.py
#
# b'    @classmethod\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/core/arrays/sparse/__init__.py
#
# b'    make_sparse_index,\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/core/arrays/sparse/array.py
#
# b'    else:  # pragma: no cover\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/core/arrays/sparse/accessor.py
#
# b'        if len(index) != N:\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/core/arrays/sparse/dtype.py
#
# b'\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/core/arrays/sparse/scipy_sparse.py
#
# b'        ind = MultiIndex.from_product([i, j])\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/core/indexes/api.py
#
# b'    itr = iter(indexes)\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/core/indexes/__init__.py
#
# IndexError('list index out of range')
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/core/indexes/frozen.py
#
# b'    __delitem__ = __delslice__ = _disabled  # type: ignore[assignment]\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/core/indexes/category.py
#
# b'        else:\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/core/indexes/datetimelike.py
#
# b'            return result\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/core/indexes/accessors.py
#
# b'            return PeriodProperties(data, orig)\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/core/indexes/multi.py
#
# b'        if not is_list_like(arr) or not is_list_like(arr[0]):\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/core/indexes/range.py
#
# b'            # Defer to Int64Index implementation\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/core/indexes/numeric.py
#
# b'    _default_dtype = np.dtype(np.float64)\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/core/indexes/extension.py
#
# b'    def _from_join_target(self, result: np.ndarray) -> ArrayLike:\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/core/indexes/timedeltas.py
#
# b'    freq, _ = dtl.maybe_infer_freq(freq)\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/core/indexes/interval.py
#
# b'            breaks = timedelta_range(start=start, end=end, periods=periods, freq=freq)\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/core/indexes/datetimes.py
#
# b'def _time_to_micros(time_obj: time) -> int:\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/core/indexes/period.py
#
# b'    data, freq = PeriodArray._generate_range(start, end, periods, freq, fields={})\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/core/indexes/base.py
#
# b'                stacklevel=4,\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/core/sparse/api.py
#
# b')\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/core/sparse/__init__.py
#
# IndexError('list index out of range')
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/core/dtypes/generic.py
#
# b'    "Type[PandasArray]",\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/core/dtypes/api.py
#
# b'    is_unsigned_integer_dtype,\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/core/dtypes/concat.py
#
# b'\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/core/dtypes/__init__.py
#
# IndexError('list index out of range')
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/core/dtypes/inference.py
#
# b'    elif dtype == np.dtype("object"):\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/core/dtypes/common.py
#
# b'        raise TypeError(f"dtype \'{dtype}\' not understood")\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/core/dtypes/cast.py
#
# b'        return isinstance(element, bytes) and len(element) <= dtype.itemsize\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/core/dtypes/dtypes.py
#
# b'        The element size of this data-type object.\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/core/dtypes/missing.py
#
# b'        checker(arr[i : i + chunk_len]).all()  # type: ignore[arg-type]\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/core/dtypes/base.py
#
# b'\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/core/strings/__init__.py
#
# b'from pandas.core.strings.base import BaseStringArrayMethods\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/core/strings/object_array.py
#
# b'                return empty_row\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/core/strings/accessor.py
#
# b'        match_list, index=index, columns=columns, dtype=dtype\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/core/strings/base.py
#
# b'    @abc.abstractmethod\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/core/util/__init__.py
#
# IndexError('list index out of range')
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/core/util/numba_.py
#
# b'            return impl\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/core/util/hashing.py
#
# b'    vals *= np.uint64(0x94D049BB133111EB)\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/core/indexers/__init__.py
#
# b'    "check_key_length",\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/core/indexers/utils.py
#
# b'        raise IndexError("arrays used as indices must be of integer or boolean type")\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/core/indexers/objects.py
#
# b'    ) -> tuple[np.ndarray, np.ndarray]:\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/core/tools/__init__.py
#
# IndexError('list index out of range')
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/core/tools/times.py
#
# b'                pass\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/core/tools/numeric.py
#
# b'        return values[0]\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/core/tools/timedeltas.py
#
# b'\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/core/tools/datetimes.py
#
# b'    from pandas.core.tools.times import to_time\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/io/sql.py
#
# b'    return pandas_sql._create_sql_schema(\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/io/api.py
#
# b')\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/io/__init__.py
#
# IndexError('list index out of range')
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/io/orc.py
#
# b'    with get_handle(path, "rb", is_text=False) as handles:\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/io/xml.py
#
# b'        compression=compression,\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/io/pickle.py
#
# b'        except UnicodeDecodeError:\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/io/html.py
#
# b'        keep_default_na=keep_default_na,\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/io/stata.py
#
# b'                name = name.replace(c, "_")\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/io/parquet.py
#
# b'        use_nullable_dtypes=use_nullable_dtypes,\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/io/common.py
#
# b'    # classes that expect bytes\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/io/date_converters.py
#
# b'            )\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/io/pytables.py
#
# b'            return self.coordinates\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/io/clipboards.py
#
# b'    else:\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/io/feather_format.py
#
# b'        return feather.read_feather(\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/io/spss.py
#
# b'        stringify_path(path), usecols=usecols, apply_value_formats=convert_categoricals\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/io/gbq.py
# b'        progress_bar=progress_bar,\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/io/clipboard/__init__.py
#
# b'# pandas aliases\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/io/excel/_xlsxwriter.py
#
# b'                )\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/io/excel/__init__.py
#
# b'\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/io/excel/_xlwt.py
#
# b'            style.num_format_str = num_format_str\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/io/excel/_base.py
#
# b'            self.close()\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/io/excel/_openpyxl.py
#
# b'                ]\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/io/excel/_odswriter.py
#
# b'        config_item_map_entry.addElement(\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/io/excel/_pyxlsb.py
#
# b'                    for data_row in data\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/io/excel/_util.py
#
# b'        result = engine_kwargs.copy()\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/io/excel/_xlrd.py
#
# b'            data.append(row)\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/io/excel/_odfreader.py
#
# b'            else:\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/io/sas/__init__.py
#
# IndexError('list index out of range')
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/io/sas/sasreader.py
#
# b'\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/io/sas/sas_constants.py
#
# b'    "TOD",\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/io/sas/sas7bdat.py
#
# b'                raise ValueError(f"unknown column type {self._column_types[j]}")\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/io/sas/sas_xport.py
#
# b'        self._lines_read += read_lines\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/io/parsers/__init__.py
#
# b')\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/io/parsers/c_parser_wrapper.py
#
# b'    elif dtype is not None:\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/io/parsers/base_parser.py
#
# b'\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/io/parsers/readers.py
#
# b'            raise ValueError("\'skipfooter\' not supported for iteration")\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/io/parsers/python_parser.py
#
# b'        raise ValueError("skipfooter cannot be negative")\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/io/json/__init__.py
#
# b'    "json_normalize",\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/io/json/_table_schema.py
#
# b'            ]\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/io/json/_json.py
#
# b'                (self.keep_default_dates and is_ok(col)) or col in convert_dates\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/io/json/_normalize.py
#
# b'json_normalize = deprecate(\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/io/formats/style_render.py
#
# b'        .replace("^", "\\\\textasciicircum ")\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/io/formats/__init__.py
#
# IndexError('list index out of range')
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/io/formats/xml.py
#
# b'        new_doc = transformer(self.root)\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/io/formats/string.py
#
# b'\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/io/formats/latex.py
#
# b'    import doctest\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/io/formats/html.py
#
# b'        super().render()\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/io/formats/css.py
#
# b'                    f"Ill-formatted attribute: expected a colon in {repr(decl)}",\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/io/formats/_color_data.py
#
# b'    "yellow": "FFFF00",\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/io/formats/printing.py
#
# b'\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/io/formats/format.py
#
# b'    if any(isinstance(x, str) for x in lines):\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/io/formats/info.py
#
# b'    """\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/io/formats/csvs.py
#
# b'            self.cols,\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/io/formats/console.py
#
# b'        pass\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/io/formats/style.py
#
# b'    else:\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/io/formats/excel.py
#
# b'            # make sure to close opened file handles\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/tests/__init__.py
#
# IndexError('list index out of range')
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/tests/test_downstream.py
#
# b'    output = exc.value.stdout.decode()\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/tests/test_aggregation.py
#
# b'    result = _make_unique_kwarg_list(order)\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/tests/test_common.py
#
# b'        result = df[frozen]\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/tests/test_take.py
#
# b'        result = algos.take(arr, [0, 0])\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/tests/test_expressions.py
#
# b'                pass\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/tests/test_sorting.py
#
# b'    result = safe_sort(values)\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/tests/test_register_accessor.py
#
# b'\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/tests/test_algos.py
#
# b'        with tm.assert_produces_warning(RuntimeWarning):\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/tests/test_errors.py
#
# b'    xpr = "This method must be defined in the concrete class Foo"\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/tests/test_multilevel.py
#
# b'        )\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/tests/test_optional_dependency.py
#
# b'\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/tests/test_flags.py
#
# b'\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/tests/test_nanops.py
#
# b'    median_expected = operation(s)\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/tests/construction/__init__.py
#
# IndexError('list index out of range')
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/tests/construction/test_extract_array.py
#
# b'    tm.assert_index_equal(res, ri)\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/tests/window/__init__.py
#
# b'        r"ignore:`np\\.int` is a deprecated alias:DeprecationWarning"\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/tests/window/test_expanding.py
#
# b'    s = s + 5000\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/tests/window/test_base_indexer.py
#
# b'    result = getattr(df.rolling(indexer), func)(*args)\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/tests/window/test_ewm.py
#
# b'    result = getattr(e, func)()\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/tests/window/test_numba.py
#
# b'            engine_kwargs=engine_kwargs, engine="numba"\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/tests/window/test_apply.py
#
# b'\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/tests/window/test_pairwise.py
#
# b'        )\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/tests/window/test_api.py
#
# b'    getattr(roll_obj, arithmetic_win_operators)()\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/tests/window/test_online.py
#
# b'            tm.assert_equal(result, expected.tail(3))\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/tests/window/test_dtypes.py
#
# b'        result = getattr(df.rolling(2, min_periods=min_periods), method)()\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/tests/window/test_rolling.py
#
# b'        dtype="float64",\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/tests/window/test_groupby.py
#
# b'            result = gb.ewm(halflife=halflife, times="C").mean()\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/tests/window/conftest.py
#
# b'        [[None, 1, 1], [None, 1, 2], [None, 3, 2], [None, 8, 1]],\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/tests/window/test_win_type.py
#
# b'    indexer = CustomIndexer()\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/tests/window/test_timeseries_window.py
#
# b'            {"column": [0.0, 1.0, 3.0, 6.0, 10.0, 15.0]}, index=df.index\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/tests/window/moments/test_moments_rolling.py
#
# b'\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/tests/window/moments/__init__.py
#
# IndexError('list index out of range')
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/pandas-master/pandas/tests/window/moments/test_moments_ewm.py
#
# b'    # pass in ints\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
# ...
# IndexError('list index out of range')
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/scikit-learn-main/sklearn/datasets/tests/data/openml/id_292/__init__.py
#
# IndexError('list index out of range')
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/scikit-learn-main/sklearn/datasets/tests/data/openml/id_42585/__init__.py
#
# IndexError('list index out of range')
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/scikit-learn-main/sklearn/datasets/tests/data/openml/id_561/__init__.py
#
# IndexError('list index out of range')
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/scikit-learn-main/sklearn/datasets/tests/data/openml/id_3/__init__.py
#
# IndexError('list index out of range')
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/scikit-learn-main/sklearn/datasets/tests/data/openml/id_61/__init__.py
#
# IndexError('list index out of range')
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/scikit-learn-main/sklearn/datasets/tests/data/openml/id_40675/__init__.py
#
# IndexError('list index out of range')
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/scikit-learn-main/sklearn/datasets/tests/data/openml/id_1/__init__.py
#
# IndexError('list index out of range')
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/scikit-learn-main/sklearn/datasets/tests/data/openml/id_2/__init__.py
#
# IndexError('list index out of range')
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/scikit-learn-main/sklearn/datasets/tests/data/openml/id_40589/__init__.py
#
# IndexError('list index out of range')
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/scikit-learn-main/sklearn/datasets/tests/data/openml/id_40966/__init__.py
#
# IndexError('list index out of range')
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/scikit-learn-main/sklearn/datasets/tests/data/openml/id_62/__init__.py
#
# IndexError('list index out of range')
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/scikit-learn-main/sklearn/datasets/tests/data/openml/id_1119/__init__.py
#
# IndexError('list index out of range')
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/scikit-learn-main/sklearn/datasets/tests/data/openml/id_40945/__init__.py
#
# IndexError('list index out of range')
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/scikit-learn-main/sklearn/datasets/data/__init__.py
#
# IndexError('list index out of range')
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/scikit-learn-main/sklearn/datasets/descr/__init__.py
#
# IndexError('list index out of range')
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/scikit-learn-main/sklearn/datasets/images/__init__.py
#
# IndexError('list index out of range')
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/scikit-learn-main/sklearn/manifold/_t_sne.py
#
# b'        """\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/scikit-learn-main/sklearn/manifold/__init__.py
#
# b'    "TSNE",\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/scikit-learn-main/sklearn/manifold/_locally_linear.py
#
# b'        for i in range(X.shape[0]):\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/scikit-learn-main/sklearn/manifold/_isomap.py
#
# b'        G_X *= -0.5\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/scikit-learn-main/sklearn/manifold/_mds.py
#
# b'        )\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/scikit-learn-main/sklearn/manifold/_spectral_embedding.py
#
# b'        """\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/scikit-learn-main/sklearn/manifold/setup.py
#
# b'    from numpy.distutils.core import setup\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/scikit-learn-main/sklearn/manifold/tests/__init__.py
#
# IndexError('list index out of range')
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/scikit-learn-main/sklearn/manifold/tests/test_locally_linear.py
#
# b'    for method in ["standard", "hessian", "modified", "ltsa"]:\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/scikit-learn-main/sklearn/manifold/tests/test_isomap.py
#
# b'    X_graph = neighbors.kneighbors_graph(X, n_neighbors=2, mode="distance")\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/scikit-learn-main/sklearn/manifold/tests/test_mds.py
#
# b'    # _pairwise attribute is set correctly\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/scikit-learn-main/sklearn/manifold/tests/test_spectral_embedding.py
#
# b'    msg = r"Attribute `_pairwise` was deprecated in version 0\\.24"\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/scikit-learn-main/sklearn/manifold/tests/test_t_sne.py
#
# b'    ).fit_transform(X)\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/scikit-learn-main/sklearn/ensemble/__init__.py
#
# b'    "HistGradientBoostingClassifier",\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/scikit-learn-main/sklearn/ensemble/_base.py
#
# b'            names mapped to their values.\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/scikit-learn-main/sklearn/ensemble/_forest.py
#
# b'        """\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/scikit-learn-main/sklearn/ensemble/_bagging.py
#
# b'\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/scikit-learn-main/sklearn/ensemble/_iforest.py
#
# b'    )\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/scikit-learn-main/sklearn/ensemble/_gb_losses.py
#
# b'    "deviance": None,  # for both, multinomial and binomial\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/scikit-learn-main/sklearn/ensemble/_stacking.py
#
# b'        else:\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/scikit-learn-main/sklearn/ensemble/_voting.py
#
# b'        """\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/scikit-learn-main/sklearn/ensemble/_weight_boosting.py
#
# b'\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/scikit-learn-main/sklearn/ensemble/_gb.py
#
# b'                "{} object has no n_classes_ attribute.".format(self.__class__.__name__)\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/scikit-learn-main/sklearn/ensemble/setup.py
#
# b'    from numpy.distutils.core import setup\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/scikit-learn-main/sklearn/ensemble/tests/test_weight_boosting.py
#
# b'    err_msg = "sample_weight cannot contain negative weight"\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/scikit-learn-main/sklearn/ensemble/tests/test_stacking.py
#
# b'    msg = "\'MyEstimator\' object has no attribute \'n_features_in_\'"\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/scikit-learn-main/sklearn/ensemble/tests/__init__.py
#
# IndexError('list index out of range')
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/scikit-learn-main/sklearn/ensemble/tests/test_common.py
#
# b'    pipe = make_pipeline(SimpleImputer(), Estimator())\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/scikit-learn-main/sklearn/ensemble/tests/test_gradient_boosting.py
#
# b'    est2 = GradientBoostingRegressor(loss=new_loss, random_state=0)\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/scikit-learn-main/sklearn/ensemble/tests/test_forest.py
#
# b'    est = FOREST_REGRESSORS[Forest](n_estimators=2, n_jobs=2, criterion=mse_criterion)\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/scikit-learn-main/sklearn/ensemble/tests/test_gradient_boosting_loss_functions.py
#
# b'        y_true, raw_predictions, sample_weight=weights, alpha=alpha\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/scikit-learn-main/sklearn/ensemble/tests/test_iforest.py
#
# b'\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/scikit-learn-main/sklearn/ensemble/tests/test_base.py
#
# b'            est1.get_params()["clf__random_state"]\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/scikit-learn-main/sklearn/ensemble/tests/test_voting.py
#
# b'\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/scikit-learn-main/sklearn/ensemble/tests/test_bagging.py
#
# b'\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/scikit-learn-main/sklearn/ensemble/_hist_gradient_boosting/__init__.py
#
# b'The implementation is a port from pygbm which is itself strongly inspired\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/scikit-learn-main/sklearn/ensemble/_hist_gradient_boosting/loss.py
#
# b'    "categorical_crossentropy": CategoricalCrossEntropy,\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/scikit-learn-main/sklearn/ensemble/_hist_gradient_boosting/gradient_boosting.py
#
# b'                )\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/scikit-learn-main/sklearn/ensemble/_hist_gradient_boosting/predictor.py
#
# b'            point.\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/scikit-learn-main/sklearn/ensemble/_hist_gradient_boosting/grower.py
#
# b'        next_free_node_idx=next_free_node_idx,\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/scikit-learn-main/sklearn/ensemble/_hist_gradient_boosting/binning.py
#
# b'                set_bitset_memoryview(known_cat_bitsets[mapped_f_idx], raw_cat_val)\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/scikit-learn-main/sklearn/ensemble/_hist_gradient_boosting/tests/__init__.py
#
# IndexError('list index out of range')
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/scikit-learn-main/sklearn/ensemble/_hist_gradient_boosting/tests/test_warm_start.py
#
# b'\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/scikit-learn-main/sklearn/ensemble/_hist_gradient_boosting/tests/test_histogram.py
#
# b'    for key in ("count", "sum_hessians", "sum_gradients"):\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/scikit-learn-main/sklearn/ensemble/_hist_gradient_boosting/tests/test_predictor.py
#
# b'        n_threads,\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/scikit-learn-main/sklearn/ensemble/_hist_gradient_boosting/tests/test_loss.py
#
# b'    )\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/scikit-learn-main/sklearn/ensemble/_hist_gradient_boosting/tests/test_monotonic_contraints.py
#
# b'        upper_bound=children_upper_bound,\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/scikit-learn-main/sklearn/ensemble/_hist_gradient_boosting/tests/test_bitset.py
#
# b'            assert in_bitset_memoryview(raw_bitset, raw_cat_val)\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/scikit-learn-main/sklearn/ensemble/_hist_gradient_boosting/tests/test_gradient_boosting.py
#
# b'    est2 = HistGradientBoostingRegressor(loss=new_loss, random_state=0)\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/scikit-learn-main/sklearn/ensemble/_hist_gradient_boosting/tests/test_grower.py
#
# b'        assert predictor.get_max_depth() < predictor_ohe.get_max_depth()\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/scikit-learn-main/sklearn/ensemble/_hist_gradient_boosting/tests/test_compare_lightgbm.py
#
# b'        acc_lightgbm = accuracy_score(y_test, pred_lightgbm)\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/scikit-learn-main/sklearn/ensemble/_hist_gradient_boosting/tests/test_splitting.py
#
# b'    left_mask = np.isin(X_binned.ravel(), expected_categories_left)\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/scikit-learn-main/sklearn/ensemble/_hist_gradient_boosting/tests/test_binning.py
#
# b'    )\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/scikit-learn-main/sklearn/svm/__init__.py
#
# b'    "SVR",\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/scikit-learn-main/sklearn/svm/_base.py
#
# b'        intercept_ = 0.0\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/scikit-learn-main/sklearn/svm/_classes.py
#
# b'                ),\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/scikit-learn-main/sklearn/svm/_bounds.py
#
# b'        return 0.5 / den\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/scikit-learn-main/sklearn/svm/setup.py
#
# b'    from numpy.distutils.core import setup\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/scikit-learn-main/sklearn/svm/tests/__init__.py
#
# IndexError('list index out of range')
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/scikit-learn-main/sklearn/svm/tests/test_sparse.py
#
# b'    with ignore_warnings(category=ConvergenceWarning):\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/scikit-learn-main/sklearn/svm/tests/test_svm.py
#
# b'    else:  # regressor\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/scikit-learn-main/sklearn/svm/tests/test_bounds.py
#
# b'    """Test that `bounded_rand_int_wrap` is defined for unsigned 32bits ints"""\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/scikit-learn-main/build_tools/generate_authors_table.py
#
# b'\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/scikit-learn-main/build_tools/github/check_wheels.py
#
# b'\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/scikit-learn-main/build_tools/github/vendor.py
#
# b'if __name__ == "__main__":\n'
#
#
# ~~~~~~~~~~~~~~~~~~
#
#  /home/benjamin/Desktop/webinars/notebooks/data/examples/lotsofcode/scikit-learn-main/build_tools/circle/list_versions.py
#
# b'            f"_downloads/scikit-learn-docs.{file_extension}>`_)"\n'

# %% [markdown]
# # Opening Excel files with pandas

# %%
import pandas as pd

# %%
df = pd.read_excel("./data/eg1.xlsx")

# %%
#df = pd.read_excel("/home/benjamin/Desktop/webinars/notebooks/data/eg1.xlsx")

# %%
df
# Out:
#      OrderDate Region         City  Category         Product  Quantity  \
# 0   2020-01-01   East       Boston      Bars          Carrot        33
# 1   2020-01-04   East       Boston  Crackers     Whole Wheat        87
# 2   2020-01-07   West  Los Angeles   Cookies  Chocolate Chip        58
# 3   2020-01-10   East     New York   Cookies  Chocolate Chip        82
# 4   2020-01-13   East       Boston   Cookies       Arrowroot        38
# ..         ...    ...          ...       ...             ...       ...
# 239 2021-12-18   East       Boston   Cookies       Arrowroot        34
# 240 2021-12-21   East       Boston   Cookies  Chocolate Chip       245
# 241 2021-12-24   East       Boston  Crackers     Whole Wheat        30
# 242 2021-12-27   West  Los Angeles      Bars            Bran        30
# 243 2021-12-30   West  Los Angeles   Cookies  Oatmeal Raisin        44
#
#      UnitPrice  TotalPrice
# 0         1.77         NaN
# 1         3.49         NaN
# 2         1.87         NaN
# 3         1.87         NaN
# 4         2.18         NaN
# ..         ...         ...
# 239       2.18         NaN
# 240       1.87         NaN
# 241       3.49         NaN
# 242       1.87         NaN
# 243       2.84         NaN
#
# [244 rows x 8 columns]

# %%
df['total_cost'] = df['Quantity']*df['UnitPrice']

# %%
df
# Out:
#      OrderDate Region         City  Category         Product  Quantity  \
# 0   2020-01-01   East       Boston      Bars          Carrot        33
# 1   2020-01-04   East       Boston  Crackers     Whole Wheat        87
# 2   2020-01-07   West  Los Angeles   Cookies  Chocolate Chip        58
# 3   2020-01-10   East     New York   Cookies  Chocolate Chip        82
# 4   2020-01-13   East       Boston   Cookies       Arrowroot        38
# ..         ...    ...          ...       ...             ...       ...
# 239 2021-12-18   East       Boston   Cookies       Arrowroot        34
# 240 2021-12-21   East       Boston   Cookies  Chocolate Chip       245
# 241 2021-12-24   East       Boston  Crackers     Whole Wheat        30
# 242 2021-12-27   West  Los Angeles      Bars            Bran        30
# 243 2021-12-30   West  Los Angeles   Cookies  Oatmeal Raisin        44
#
#      UnitPrice  TotalPrice  total_cost
# 0         1.77         NaN       58.41
# 1         3.49         NaN      303.63
# 2         1.87         NaN      108.46
# 3         1.87         NaN      153.34
# 4         2.18         NaN       82.84
# ..         ...         ...         ...
# 239       2.18         NaN       74.12
# 240       1.87         NaN      458.15
# 241       3.49         NaN      104.70
# 242       1.87         NaN       56.10
# 243       2.84         NaN      124.96
#
# [244 rows x 9 columns]

# %%
df.to_excel("./data/result.xlsx")
