# %%
import pandas as pd
import numpy as np
import random
from sklearn import preprocessing
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import ShuffleSplit
from sklearn.model_selection import train_test_split

# %%
churn_2_classes = pd.read_csv('./data/churn_2_classes.csv', index_col=0)
churn_3_classes = pd.read_csv('./data/churn_3_classes.csv', index_col=0)

# %%
churn_2_classes
# Out:
#       days_since_last_order median_order_type  days_since_last_contact  \
# 2288                      1   raw_ingredients                       12
# 869                       4    finished_goods                        6
# 4619                      4   raw_ingredients                        1
# 5651                     12   raw_ingredients                        9
# 6237                     11   raw_ingredients                        4
# ...                     ...               ...                      ...
# 3841                      7   raw_ingredients                        2
# 4279                      5   raw_ingredients                        7
# 8813                      7    finished_goods                       12
# 8294                      5   raw_ingredients                        2
# 7855                      8    finished_goods                        6
#
#       monthly_mean_order_vol  yearly_mean_cust_rev  status
# 2288                    1483                  1466  active
# 869                     1400                  1279  active
# 4619                    1419                  1218  active
# 5651                    1184                  1443  active
# 6237                     614                   914  active
# ...                      ...                   ...     ...
# 3841                    1362                  1277  active
# 4279                     637                   635  active
# 8813                     641                   777  active
# 8294                     519                  1290  active
# 7855                     522                   947  active
#
# [11000 rows x 6 columns]

# %%
df1 = churn_2_classes[churn_2_classes['status'] == 'active']
df2 = churn_2_classes[churn_2_classes['status'] == 'cancelled']

# %%
df1 = df1.sample(frac=0.1) # frac = len(df2)/len(df1)

# %%
#now the classes are the same size

# %%
df = pd.concat([df1,df2], ignore_index=True)
df
# Out:
#       days_since_last_order median_order_type  days_since_last_contact  \
# 0                         4   raw_ingredients                       10
# 1                         9   raw_ingredients                        9
# 2                         4   raw_ingredients                        5
# 3                         6   raw_ingredients                       11
# 4                         1   raw_ingredients                        2
# ...                     ...               ...                      ...
# 1995                     12    finished_goods                       13
# 1996                     16    finished_goods                       18
# 1997                     16    finished_goods                        9
# 1998                     18    finished_goods                       16
# 1999                     14    finished_goods                       15
#
#       monthly_mean_order_vol  yearly_mean_cust_rev     status
# 0                       1020                  1301     active
# 1                       1447                   839     active
# 2                       1156                   835     active
# 3                        604                  1195     active
# 4                       1030                   700     active
# ...                      ...                   ...        ...
# 1995                    1176                  1283  cancelled
# 1996                     860                  1301  cancelled
# 1997                    1355                   460  cancelled
# 1998                     673                   433  cancelled
# 1999                     606                  1126  cancelled
#
# [2000 rows x 6 columns]

# %%
churn_3_classes
# Out:
#       days_since_last_order median_order_type  days_since_last_contact  \
# 9728                      2   raw_ingredients                       10
# 3374                     10   raw_ingredients                        4
# 884                      11    finished_goods                        7
# 8910                     12   raw_ingredients                       14
# 9075                     10   raw_ingredients                        6
# ...                     ...               ...                      ...
# 8113                     12   raw_ingredients                       12
# 9809                      6   raw_ingredients                        5
# 7739                      9   raw_ingredients                        4
# 256                       9    finished_goods                       11
# 2355                      7   raw_ingredients                        4
#
#       monthly_mean_order_vol  yearly_mean_cust_rev  status
# 9728                     813                  1206  active
# 3374                    1402                  1246  active
# 884                      635                  1479  active
# 8910                     771                   809  active
# 9075                    1362                  1185  active
# ...                      ...                   ...     ...
# 8113                    1127                   560  active
# 9809                    1280                   897  active
# 7739                    1147                   549  active
# 256                     1100                  1322  active
# 2355                    1497                  1018  active
#
# [12000 rows x 6 columns]

# %%
#harder with 3 classes

df1 = churn_3_classes[churn_3_classes['status'] == 'active']
df2 = churn_3_classes[churn_3_classes['status'] == 'cancelled']
df3 = churn_3_classes[churn_3_classes['status'] == 'paused']

# %%
df1.shape[0], df2.shape[0], df3.shape[0]
# Out:
# (10000, 1000, 1000)

# %%
#in this case 
df1 = df1.sample(frac=0.1)
#also works...

# %%
df = pd.concat([df1,df2,df3], ignore_index=True)
df
# Out:
#       days_since_last_order median_order_type  days_since_last_contact  \
# 0                        12   raw_ingredients                        1
# 1                         2   raw_ingredients                       13
# 2                        12    finished_goods                        6
# 3                         3   raw_ingredients                        9
# 4                         6   raw_ingredients                        3
# ...                     ...               ...                      ...
# 2995                     10   raw_ingredients                       23
# 2996                     29   raw_ingredients                       11
# 2997                     22   raw_ingredients                       21
# 2998                     37   raw_ingredients                       15
# 2999                     27   raw_ingredients                       15
#
#       monthly_mean_order_vol  yearly_mean_cust_rev  status
# 0                       1203                   628  active
# 1                       1026                   928  active
# 2                        701                   501  active
# 3                        863                  1369  active
# 4                       1116                   923  active
# ...                      ...                   ...     ...
# 2995                     888                   867  paused
# 2996                     826                   499  paused
# 2997                    1131                   442  paused
# 2998                    1170                  1278  paused
# 2999                     839                  1294  paused
#
# [3000 rows x 6 columns]

# %%
rfc = RandomForestClassifier(max_depth=10, n_estimators=100)

# %%
y = df['status']
le = preprocessing.LabelEncoder()
le.fit(y)
# Out:
# LabelEncoder()

# %%
df.loc[:,'status'] = le.transform(df['status'])
df
# Out:
#       days_since_last_order median_order_type  days_since_last_contact  \
# 0                        12   raw_ingredients                        1
# 1                         2   raw_ingredients                       13
# 2                        12    finished_goods                        6
# 3                         3   raw_ingredients                        9
# 4                         6   raw_ingredients                        3
# ...                     ...               ...                      ...
# 2995                     10   raw_ingredients                       23
# 2996                     29   raw_ingredients                       11
# 2997                     22   raw_ingredients                       21
# 2998                     37   raw_ingredients                       15
# 2999                     27   raw_ingredients                       15
#
#       monthly_mean_order_vol  yearly_mean_cust_rev  status
# 0                       1203                   628       0
# 1                       1026                   928       0
# 2                        701                   501       0
# 3                        863                  1369       0
# 4                       1116                   923       0
# ...                      ...                   ...     ...
# 2995                     888                   867       2
# 2996                     826                   499       2
# 2997                    1131                   442       2
# 2998                    1170                  1278       2
# 2999                     839                  1294       2
#
# [3000 rows x 6 columns]

# %%
X = df.drop(['status', 'median_order_type'], axis=1)

# %%
rfc.fit( X,y )
# Out:
# RandomForestClassifier(max_depth=10)

# %%
y = churn_2_classes['status']
le = preprocessing.LabelEncoder()
le.fit(y)

churn_2_classes.loc[:,'status'] = le.transform(churn_2_classes['status'])
churn_2_classes
# Out:
#       days_since_last_order median_order_type  days_since_last_contact  \
# 2288                      1   raw_ingredients                       12
# 869                       4    finished_goods                        6
# 4619                      4   raw_ingredients                        1
# 5651                     12   raw_ingredients                        9
# 6237                     11   raw_ingredients                        4
# ...                     ...               ...                      ...
# 3841                      7   raw_ingredients                        2
# 4279                      5   raw_ingredients                        7
# 8813                      7    finished_goods                       12
# 8294                      5   raw_ingredients                        2
# 7855                      8    finished_goods                        6
#
#       monthly_mean_order_vol  yearly_mean_cust_rev  status
# 2288                    1483                  1466       0
# 869                     1400                  1279       0
# 4619                    1419                  1218       0
# 5651                    1184                  1443       0
# 6237                     614                   914       0
# ...                      ...                   ...     ...
# 3841                    1362                  1277       0
# 4279                     637                   635       0
# 8813                     641                   777       0
# 8294                     519                  1290       0
# 7855                     522                   947       0
#
# [11000 rows x 6 columns]

# %%
X = churn_2_classes.drop(['status', 'median_order_type'], axis=1)

# %%
rfc = RandomForestClassifier(max_depth=10, n_estimators=10, class_weight="balanced")
rfc.fit( X, y )
# Out:
# RandomForestClassifier(class_weight='balanced', max_depth=10, n_estimators=10)

# %%
scores = []
ss = ShuffleSplit(n_splits=3, test_size=0.25)

for train_index, test_index in ss.split(X):
    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    y_train, y_test = y.iloc[train_index], y.iloc[test_index]
    
    rfc.fit(X_train, y_train)
    
    preds = rfc.predict( X_test )

    scores.append(accuracy_score(preds, y_test))

# %%
#more valid, but harder to interpret
scores
# Out:
# [0.7810909090909091, 0.7734545454545455, 0.8254545454545454]

# %%
rfc = RandomForestClassifier(max_depth=100, n_estimators=100, class_weight="balanced")
rfc.fit( X, y )
# Out:
# RandomForestClassifier(class_weight='balanced', max_depth=100)

# %%
scores = []
ss = ShuffleSplit(n_splits=3, test_size=0.25)

for train_index, test_index in ss.split(X):
    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    y_train, y_test = y.iloc[train_index], y.iloc[test_index]
    
    rfc.fit(X_train, y_train)
    
    preds = rfc.predict( X_test )

    scores.append(accuracy_score(preds, y_test))

# %%
# better scores with more params
scores
# Out:
# [0.9683636363636363, 0.9687272727272728, 0.9665454545454546]

# %%
#pivot tables

# %%
suppliers = pd.read_csv("https://www.dropbox.com/s/jjbacrux6bc1b4s/suppliers.csv?dl=1")
# demand = pd.read_csv("https://www.dropbox.com/s/0yikq3pugq87vl9/demand_forecasts.csv?dl=1")
# recipes = pd.read_csv("https://www.dropbox.com/s/az97voeh6i8x3i2/recipes.csv?dl=1")

# %%
suppliers
# Out:
#      supp_id ingredient_uuid  cost_per_unit unit_name country_of_origin  \
# 0   megacorp           cocoa         2500.0     tonne             ghana
# 1   megacorp     milk_powder         3200.0     tonne            france
# 2   megacorp        hazelnut         1918.0     tonne            turkey
# 3   megacorp           sugar          457.0     tonne            brazil
# 4   megacorp         vanilla          237.0     tonne             china
# 5   omni_inc           cocoa         2400.0     tonne     cote d'ivoire
# 6   omni_inc     milk_powder         3120.0     tonne       switzerland
# 7   omni_inc        hazelnut         1925.0     tonne             italy
# 8   omni_inc           sugar          465.0     tonne             india
# 9   omni_inc         vanilla          201.0     tonne         indonesia
# 10  acme_inc           cocoa         2370.0     tonne         indonesia
# 11  acme_inc     milk_powder         3190.0     tonne           denmark
# 12  acme_inc        hazelnut         1817.0     tonne               usa
# 13  acme_inc           sugar          476.0     tonne             china
# 14  acme_inc         vanilla          185.0     tonne        madagascar
#
#     total_tax_per_unit  time_to_deliver
# 0                   14               12
# 1                   12                3
# 2                   12                4
# 3                    5                9
# 4                    3               10
# 5                   14               12
# 6                    0                2
# 7                   12                3
# 8                    5               12
# 9                    3               12
# 10                  14               12
# 11                  12                3
# 12                  12                8
# 13                   5               10
# 14                   3               12

# %%
pd.pivot(suppliers, values="ingredient_uuid", columns=['supp_id'])
# Out:
# supp_id     acme_inc     megacorp     omni_inc
# 0                NaN        cocoa          NaN
# 1                NaN  milk_powder          NaN
# 2                NaN     hazelnut          NaN
# 3                NaN        sugar          NaN
# 4                NaN      vanilla          NaN
# 5                NaN          NaN        cocoa
# 6                NaN          NaN  milk_powder
# 7                NaN          NaN     hazelnut
# 8                NaN          NaN        sugar
# 9                NaN          NaN      vanilla
# 10             cocoa          NaN          NaN
# 11       milk_powder          NaN          NaN
# 12          hazelnut          NaN          NaN
# 13             sugar          NaN          NaN
# 14           vanilla          NaN          NaN

# %%
pd.pivot(suppliers, values="total_tax_per_unit", columns=['supp_id'])
# Out:
# supp_id  acme_inc  megacorp  omni_inc
# 0             NaN      14.0       NaN
# 1             NaN      12.0       NaN
# 2             NaN      12.0       NaN
# 3             NaN       5.0       NaN
# 4             NaN       3.0       NaN
# 5             NaN       NaN      14.0
# 6             NaN       NaN       0.0
# 7             NaN       NaN      12.0
# 8             NaN       NaN       5.0
# 9             NaN       NaN       3.0
# 10           14.0       NaN       NaN
# 11           12.0       NaN       NaN
# 12           12.0       NaN       NaN
# 13            5.0       NaN       NaN
# 14            3.0       NaN       NaN

# %%
pd.pivot(suppliers,index="ingredient_uuid", values="total_tax_per_unit", columns=['supp_id'])
# Out:
# supp_id          acme_inc  megacorp  omni_inc
# ingredient_uuid
# cocoa                  14        14        14
# hazelnut               12        12        12
# milk_powder            12        12         0
# sugar                   5         5         5
# vanilla                 3         3         3

# %%
pd.pivot(suppliers, index="ingredient_uuid", values="time_to_deliver", columns=['supp_id'])
# Out:
# supp_id          acme_inc  megacorp  omni_inc
# ingredient_uuid
# cocoa                  12        12        12
# hazelnut                8         4         3
# milk_powder             3         3         2
# sugar                  10         9        12
# vanilla                12        10        12

# %%
pd.pivot(suppliers, values="ingredient_uuid", columns=['supp_id'])
# Out:
# supp_id     acme_inc     megacorp     omni_inc
# 0                NaN        cocoa          NaN
# 1                NaN  milk_powder          NaN
# 2                NaN     hazelnut          NaN
# 3                NaN        sugar          NaN
# 4                NaN      vanilla          NaN
# 5                NaN          NaN        cocoa
# 6                NaN          NaN  milk_powder
# 7                NaN          NaN     hazelnut
# 8                NaN          NaN        sugar
# 9                NaN          NaN      vanilla
# 10             cocoa          NaN          NaN
# 11       milk_powder          NaN          NaN
# 12          hazelnut          NaN          NaN
# 13             sugar          NaN          NaN
# 14           vanilla          NaN          NaN

# %%
pd.pivot_table(suppliers, values="total_tax_per_unit", columns=['supp_id'], aggfunc=np.mean)
# Out:
# supp_id             acme_inc  megacorp  omni_inc
# total_tax_per_unit       9.2       9.2       6.8

# %%
pd.pivot_table(suppliers, values="total_tax_per_unit", columns=['supp_id'], aggfunc=np.max)
# Out:
# supp_id             acme_inc  megacorp  omni_inc
# total_tax_per_unit        14        14        14

# %%
pd.pivot_table(suppliers, values="total_tax_per_unit", columns=['supp_id'], aggfunc=np.min)
# Out:
# supp_id             acme_inc  megacorp  omni_inc
# total_tax_per_unit         3         3         0

# %%
pd.pivot_table(suppliers, values="total_tax_per_unit", columns=['ingredient_uuid'], aggfunc=np.min)
# Out:
# ingredient_uuid     cocoa  hazelnut  milk_powder  sugar  vanilla
# total_tax_per_unit     14        12            0      5        3

# %%
pd.pivot_table(suppliers, values=["total_tax_per_unit", "time_to_deliver"], columns=['supp_id'], aggfunc=np.min)
# Out:
# supp_id             acme_inc  megacorp  omni_inc
# time_to_deliver            3         3         2
# total_tax_per_unit         3         3         0

# %%
pd.pivot_table(suppliers, values=["total_tax_per_unit"], columns=['supp_id', 'ingredient_uuid'], aggfunc=np.min)
# Out:
# supp_id            acme_inc                                    megacorp  \
# ingredient_uuid       cocoa hazelnut milk_powder sugar vanilla    cocoa
# total_tax_per_unit       14       12          12     5       3       14
#
# supp_id                                               omni_inc           \
# ingredient_uuid    hazelnut milk_powder sugar vanilla    cocoa hazelnut
# total_tax_per_unit       12          12     5       3       14       12
#
# supp_id
# ingredient_uuid    milk_powder sugar vanilla
# total_tax_per_unit           0     5       3

# %%
q=suppliers.set_index(['supp_id', 'ingredient_uuid'])
q
# Out:
#                           cost_per_unit unit_name country_of_origin  \
# supp_id  ingredient_uuid
# megacorp cocoa                   2500.0     tonne             ghana
#          milk_powder             3200.0     tonne            france
#          hazelnut                1918.0     tonne            turkey
#          sugar                    457.0     tonne            brazil
#          vanilla                  237.0     tonne             china
# omni_inc cocoa                   2400.0     tonne     cote d'ivoire
#          milk_powder             3120.0     tonne       switzerland
#          hazelnut                1925.0     tonne             italy
#          sugar                    465.0     tonne             india
#          vanilla                  201.0     tonne         indonesia
# acme_inc cocoa                   2370.0     tonne         indonesia
#          milk_powder             3190.0     tonne           denmark
#          hazelnut                1817.0     tonne               usa
#          sugar                    476.0     tonne             china
#          vanilla                  185.0     tonne        madagascar
#
#                           total_tax_per_unit  time_to_deliver
# supp_id  ingredient_uuid
# megacorp cocoa                            14               12
#          milk_powder                      12                3
#          hazelnut                         12                4
#          sugar                             5                9
#          vanilla                           3               10
# omni_inc cocoa                            14               12
#          milk_powder                       0                2
#          hazelnut                         12                3
#          sugar                             5               12
#          vanilla                           3               12
# acme_inc cocoa                            14               12
#          milk_powder                      12                3
#          hazelnut                         12                8
#          sugar                             5               10
#          vanilla                           3               12

# %%
q.unstack()
# Out:
#                 cost_per_unit                                     unit_name  \
# ingredient_uuid         cocoa hazelnut milk_powder  sugar vanilla     cocoa
# supp_id
# acme_inc               2370.0   1817.0      3190.0  476.0   185.0     tonne
# megacorp               2500.0   1918.0      3200.0  457.0   237.0     tonne
# omni_inc               2400.0   1925.0      3120.0  465.0   201.0     tonne
#
#                                                      ... total_tax_per_unit  \
# ingredient_uuid hazelnut milk_powder  sugar vanilla  ...              cocoa
# supp_id                                              ...
# acme_inc           tonne       tonne  tonne   tonne  ...                 14
# megacorp           tonne       tonne  tonne   tonne  ...                 14
# omni_inc           tonne       tonne  tonne   tonne  ...                 14
#
#                                                    time_to_deliver           \
# ingredient_uuid hazelnut milk_powder sugar vanilla           cocoa hazelnut
# supp_id
# acme_inc              12          12     5       3              12        8
# megacorp              12          12     5       3              12        4
# omni_inc              12           0     5       3              12        3
#
#
# ingredient_uuid milk_powder sugar vanilla
# supp_id
# acme_inc                  3    10      12
# megacorp                  3     9      10
# omni_inc                  2    12      12
#
# [3 rows x 25 columns]

# %%
q.stack().to_frame(name="some new name")
# Out:
#                                             some new name
# supp_id  ingredient_uuid
# megacorp cocoa           cost_per_unit             2500.0
#                          unit_name                  tonne
#                          country_of_origin          ghana
#                          total_tax_per_unit            14
#                          time_to_deliver               12
# ...                                                   ...
# acme_inc vanilla         cost_per_unit              185.0
#                          unit_name                  tonne
#                          country_of_origin     madagascar
#                          total_tax_per_unit             3
#                          time_to_deliver               12
#
# [75 rows x 1 columns]

# %%
q.unstack(0)
# Out:
#                 cost_per_unit                   unit_name                    \
# supp_id              acme_inc megacorp omni_inc  acme_inc megacorp omni_inc
# ingredient_uuid
# cocoa                  2370.0   2500.0   2400.0     tonne    tonne    tonne
# hazelnut               1817.0   1918.0   1925.0     tonne    tonne    tonne
# milk_powder            3190.0   3200.0   3120.0     tonne    tonne    tonne
# sugar                   476.0    457.0    465.0     tonne    tonne    tonne
# vanilla                 185.0    237.0    201.0     tonne    tonne    tonne
#
#                 country_of_origin                         total_tax_per_unit  \
# supp_id                  acme_inc megacorp       omni_inc           acme_inc
# ingredient_uuid
# cocoa                   indonesia    ghana  cote d'ivoire                 14
# hazelnut                      usa   turkey          italy                 12
# milk_powder               denmark   france    switzerland                 12
# sugar                       china   brazil          india                  5
# vanilla                madagascar    china      indonesia                  3
#
#                                   time_to_deliver
# supp_id         megacorp omni_inc        acme_inc megacorp omni_inc
# ingredient_uuid
# cocoa                 14       14              12       12       12
# hazelnut              12       12               8        4        3
# milk_powder           12        0               3        3        2
# sugar                  5        5              10        9       12
# vanilla                3        3              12       10       12

# %%
q.unstack(1)
# Out:
#                 cost_per_unit                                     unit_name  \
# ingredient_uuid         cocoa hazelnut milk_powder  sugar vanilla     cocoa
# supp_id
# acme_inc               2370.0   1817.0      3190.0  476.0   185.0     tonne
# megacorp               2500.0   1918.0      3200.0  457.0   237.0     tonne
# omni_inc               2400.0   1925.0      3120.0  465.0   201.0     tonne
#
#                                                      ... total_tax_per_unit  \
# ingredient_uuid hazelnut milk_powder  sugar vanilla  ...              cocoa
# supp_id                                              ...
# acme_inc           tonne       tonne  tonne   tonne  ...                 14
# megacorp           tonne       tonne  tonne   tonne  ...                 14
# omni_inc           tonne       tonne  tonne   tonne  ...                 14
#
#                                                    time_to_deliver           \
# ingredient_uuid hazelnut milk_powder sugar vanilla           cocoa hazelnut
# supp_id
# acme_inc              12          12     5       3              12        8
# megacorp              12          12     5       3              12        4
# omni_inc              12           0     5       3              12        3
#
#
# ingredient_uuid milk_powder sugar vanilla
# supp_id
# acme_inc                  3    10      12
# megacorp                  3     9      10
# omni_inc                  2    12      12
#
# [3 rows x 25 columns]

# %%
q.melt()
# Out:
#            variable   value
# 0     cost_per_unit  2500.0
# 1     cost_per_unit  3200.0
# 2     cost_per_unit  1918.0
# 3     cost_per_unit   457.0
# 4     cost_per_unit   237.0
# ..              ...     ...
# 70  time_to_deliver      12
# 71  time_to_deliver       3
# 72  time_to_deliver       8
# 73  time_to_deliver      10
# 74  time_to_deliver      12
#
# [75 rows x 2 columns]

# %%
suppliers.melt()
# Out:
#             variable     value
# 0            supp_id  megacorp
# 1            supp_id  megacorp
# 2            supp_id  megacorp
# 3            supp_id  megacorp
# 4            supp_id  megacorp
# ..               ...       ...
# 100  time_to_deliver        12
# 101  time_to_deliver         3
# 102  time_to_deliver         8
# 103  time_to_deliver        10
# 104  time_to_deliver        12
#
# [105 rows x 2 columns]

# %%
suppliers.melt(id_vars=['supp_id'])
# Out:
#      supp_id         variable        value
# 0   megacorp  ingredient_uuid        cocoa
# 1   megacorp  ingredient_uuid  milk_powder
# 2   megacorp  ingredient_uuid     hazelnut
# 3   megacorp  ingredient_uuid        sugar
# 4   megacorp  ingredient_uuid      vanilla
# ..       ...              ...          ...
# 85  acme_inc  time_to_deliver           12
# 86  acme_inc  time_to_deliver            3
# 87  acme_inc  time_to_deliver            8
# 88  acme_inc  time_to_deliver           10
# 89  acme_inc  time_to_deliver           12
#
# [90 rows x 3 columns]

# %%
suppliers.melt(id_vars=['supp_id', 'ingredient_uuid'])
# Out:
#      supp_id ingredient_uuid         variable   value
# 0   megacorp           cocoa    cost_per_unit  2500.0
# 1   megacorp     milk_powder    cost_per_unit  3200.0
# 2   megacorp        hazelnut    cost_per_unit  1918.0
# 3   megacorp           sugar    cost_per_unit   457.0
# 4   megacorp         vanilla    cost_per_unit   237.0
# ..       ...             ...              ...     ...
# 70  acme_inc           cocoa  time_to_deliver      12
# 71  acme_inc     milk_powder  time_to_deliver       3
# 72  acme_inc        hazelnut  time_to_deliver       8
# 73  acme_inc           sugar  time_to_deliver      10
# 74  acme_inc         vanilla  time_to_deliver      12
#
# [75 rows x 4 columns]

# %%
suppliers.melt(id_vars=['supp_id', 'ingredient_uuid']).T
# Out:
#                             0              1              2              3   \
# supp_id               megacorp       megacorp       megacorp       megacorp
# ingredient_uuid          cocoa    milk_powder       hazelnut          sugar
# variable         cost_per_unit  cost_per_unit  cost_per_unit  cost_per_unit
# value                   2500.0         3200.0         1918.0          457.0
#
#                             4              5              6              7   \
# supp_id               megacorp       omni_inc       omni_inc       omni_inc
# ingredient_uuid        vanilla          cocoa    milk_powder       hazelnut
# variable         cost_per_unit  cost_per_unit  cost_per_unit  cost_per_unit
# value                    237.0         2400.0         3120.0         1925.0
#
#                             8              9   ...               65  \
# supp_id               omni_inc       omni_inc  ...         omni_inc
# ingredient_uuid          sugar        vanilla  ...            cocoa
# variable         cost_per_unit  cost_per_unit  ...  time_to_deliver
# value                    465.0          201.0  ...               12
#
#                               66               67               68  \
# supp_id                 omni_inc         omni_inc         omni_inc
# ingredient_uuid      milk_powder         hazelnut            sugar
# variable         time_to_deliver  time_to_deliver  time_to_deliver
# value                          2                3               12
#
#                               69               70               71  \
# supp_id                 omni_inc         acme_inc         acme_inc
# ingredient_uuid          vanilla            cocoa      milk_powder
# variable         time_to_deliver  time_to_deliver  time_to_deliver
# value                         12               12                3
#
#                               72               73               74
# supp_id                 acme_inc         acme_inc         acme_inc
# ingredient_uuid         hazelnut            sugar          vanilla
# variable         time_to_deliver  time_to_deliver  time_to_deliver
# value                          8               10               12
#
# [4 rows x 75 columns]
